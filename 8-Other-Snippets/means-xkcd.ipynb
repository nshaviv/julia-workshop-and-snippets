# %% [markdown]
# https://discourse.julialang.org/t/seven-lines-of-julia-examples-sought/50416/34?page=3

# %% [markdown]
# ![means-xkcd.png](attachment:means-xkcd.png)

# %%
using Statistics
F(x) = [mean(x), prod(x)^(1/length(x)), median(x)]
Fⁿ(x,n) = ∘(fill(F,n)...)(x)
Fⁿ([1,1,2,3,5],100)
# Out:
# 3-element Vector{Float64}:
#  2.089057949736859
#  2.089057949736859
#  2.089057949736859

# %% [markdown]
# Note: \circ<TAB>  to get the ∘ symbol and ^n<TAB> to get ⁿ
